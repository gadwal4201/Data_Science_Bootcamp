# %% [markdown]
# # Data Types

# %%
# Integer type
age = 30
print(age)  # Output: 30
print(type(age))  # Output: <class 'int'>
# Out:
# 30
# <class 'int'>

# %%
result = "hello" + str(age)
result
# Out:
# 'hello30'
