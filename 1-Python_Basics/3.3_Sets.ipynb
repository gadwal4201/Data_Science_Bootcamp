# %% [markdown]
# # Sets

# %%
# create a set
mya_set = {1, 2, 3, 4, 5}
print(mya_set)
print(type(mya_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
s = set([1, 2, 3,3,4, 4, 5])
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
lst = [1, 2, 3,3,4, 4, 5]
print(lst)
s = set(lst)
print(s)
# Out:
# [1, 2, 3, 3, 4, 4, 5]
# {1, 2, 3, 4, 5}

# %%
s.add(6)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.remove(3)
print(s)
# Out:
# {1, 2, 4, 5, 6}

# %%
s.append(7) # This will raise an error because sets do not have an append method
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s.append(7)
#       2 print(s)
#
# AttributeError: 'set' object has no attribute 'append'

# %%
s.discard(6) # This will not raise an error even if 7 is not in the set
print(s)
# Out:
# {1, 2, 4, 5}

# %%
s.pop() # This will remove and return an arbitrary element from the set
print(s)
# Out:
# {2, 4, 5}

# %%
s.clear() # This will remove all elements from the set
print(s)
# Out:
# set()

# %% [markdown]
# # Set Membership test

# %%
my_set = {1, 2, 3, 4, 5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(3 in my_set) # This will return True because 3 is in the set
print(10 in my_set) # This will return False because 10 is not in the set
# Out:
# True
# False

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print(union_set)
intersection_set = set1.intersection(set2)
print(intersection_set)
difference_set = set1.difference(set2)
print(difference_set)
symmetric_difference_set = set1.symmetric_difference(set2)
print(symmetric_difference_set)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}

# %%
set1.update(set2) # This will add all elements of set2 to set1
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.intersection_update(set2) # This will keep only the elements that are in both set1 and set2
print(set1)
# Out:
# {3, 4, 5}

# %%
print(set1.issubset(set2)) # This will return True if set1 is a subset of set2
print(set1.issuperset(set2)) # This will return True if set1 is a superset of set2
print(set1.isdisjoint(set2)) # This will return True if set1 and set2 have no elements in common
# Out:
# False
# False
# False

# %%
text = "In this tutorial, we will learn about sets in Python. A set is an unordered collection of unique elements. Sets are useful for storing and manipulating data that does not require a specific order and does not allow duplicates."
words = text.split()
unique_words = set(words)
print(unique_words)
# Out:
# {'and', 'In', 'learn', 'will', 'collection', 'is', 'Python.', 'storing', 'order', 'unordered', 'an', 'not', 'unique', 'duplicates.', 'Sets', 'useful', 'this', 'we', 'of', 'tutorial,', 'in', 'for', 'specific', 'data', 'about', 'sets', 'does', 'allow', 'A', 'require', 'are', 'that', 'manipulating', 'set', 'a', 'elements.'}
